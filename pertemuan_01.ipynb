# %% [markdown]
# <a href="https://colab.research.google.com/github/gellagi123-lang/pemograman-dasar01/blob/main/pertemuan_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Muhammad Alfariji"
tanggal_lahir = "12-April-2004"
umur = 22
alamat = "Jl Kartini 2 No 51 RT001/RW002"
jurusan = "TRPE"
semester = 3
kelas = "Malam A"
nim = 4232511005
matakuliah = 'Pemograman Dasar'
status_lulus = False


print (nama)
print (tanggal_lahir)
print (umur)
print (alamat)
print (jurusan)
print (semester)
print (kelas)
print (nim)
print (matakuliah)
print (status_lulus)
# Out:
# Muhammad Alfariji
# 12-April-2004
# 22
# Jl Kartini 2 No 51 RT001/RW002
# TRPE
# 3
# Malam A
# 4232511005
# Pemograman Dasar
# False
