# %% [markdown]
# <a href="https://colab.research.google.com/github/gellagi123-lang/pemograman-dasar01/blob/main/Salinan_Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Jawaban Latihan 1

voltage = 18
current = 6
cell_type = "Monocrystalline"

print(voltage)
print(current)
print(cell_type)
# Out:
# 18
# 6
# Monocrystalline

# %%
# Jawaban Latihan 2

jumlah_panel = 10
tegangan = 18.5
aktif = True
jenis_komponen = "Monocrystalline"

print(jumlah_panel)
print(type(jumlah_panel))

print(tegangan)print(type(tegangan))

print(aktif)
print(type(aktif))

print(jenis_komponen)
print(type(jenis_komponen))
# Out:
# 10
# <class 'int'>
# 18.5
# <class 'float'>
# True
# <class 'bool'>
# Monocrystalline
# <class 'str'>

# %%
# Latihan 3
nama = "PLTS Nunukan"
jumlah = 240
tegangan = 48.5
aktif = True

print(type(nama))
print(type(jumlah))
print(type(tegangan))
print(type(aktif))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# Latihan 4
tegangan = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

print(tegangan[0])
print(tegangan[-1])

tegangan.append(222.0)

print(len(tegangan))
# Out:
# 217.5
# 216.9
# 7

# %%
# Latihan 5
motor = {
    "nama": "Motor-1",
    "daya_kW": 5.5,
    "tegangan_V": 380,
    "rpm": 1500
}

print(motor["rpm"])

motor["rpm"] = 1800

print(motor)
# Out:
# 1500
# {'nama': 'Motor-1', 'daya_kW': 5.5, 'tegangan_V': 380, 'rpm': 1800}

# %%
# === LATIHAN 6 ===
pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80, "status": "pemeliharaan"}
]

print("Nama unit kedua:", pembangkit[1]["nama"])
pembangkit[0]["status"] = "siaga"
print("\nSetelah ubah status Unit-1:", pembangkit[0])
unit_baru = {"nama": "Unit-4", "kapasitas_MW": 200, "status": "operasi"}
pembangkit.append(unit_baru)
print("\n=== Semua Data Pembangkit ===")
for unit in pembangkit:
    print(unit)
# Out:
# Nama unit kedua: Unit-2
#
# Setelah ubah status Unit-1: {'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'siaga'}
#
# === Semua Data Pembangkit ===
# {'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'siaga'}
# {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}
# {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'pemeliharaan'}
# {'nama': 'Unit-4', 'kapasitas_MW': 200, 'status': 'operasi'}
